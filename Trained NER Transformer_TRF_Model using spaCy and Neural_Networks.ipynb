# %%
import spacy
nlp = spacy.load("en_core_web_trf")

# %%
import os
files = os.listdir("C:/Users/RECAM/Large_module_NER")
files
# Out:
# ['ASH - St Johns Mosaic Lease - 09142021 (signed)_Text.txt',
#  'contract.txt',
#  'predictions.txt']

# %%
from pathlib import Path
import colored

text = ""
for file in files:
    with open(os.path.join("C:/Users/RECAM/Large_module_NER", file), "r", encoding="utf8") as f:
        file_path = os.path.join("C:/Users/RECAM/Large_module_NER", file)
        text = text + "\n\n\n" + file_path + "\n\n\n" + f.read()
    doc = nlp(text)
    # Do something with the doc object

# %%
#Import the requisite library
# import spacy

#Build upon the spaCy Small Model
# nlp = spacy.load("en_core_web_sm")

#Sample text
# text = "I had fever for past 10 days can I take Dolo tablet"

corpus = []

# doc = nlp(text)
for sent in doc.sents:
    corpus.append(sent.text)

#Build upon the spaCy Small Model
nlp = spacy.blank("en")

#Create the EntityRuler
ruler = nlp.add_pipe("entity_ruler")

#List of Entities and Patterns
patterns = [
               {"label": "Effective", "pattern": "Effective Date"}, 
               {"label": "Commencement", "pattern": "Commencement Date"}, 
               {"label": "EXPIRATION", "pattern": "EXPIRATION DATE"}, 
               {"label": "City", "pattern": "Fletcher"}, 
               {"label": "State", "pattern": "NC"}, 
               {"label": "LL", "pattern": "Landlord"}, 
               {"label": "TT", "pattern": "Tenant"}, 
               {"label": "RN", "pattern": "Renewal"}, 
               {"label": "Lease", "pattern": "LEASE AGREEMENT"},   
               {"label": "Location", "pattern": "address"},
               {"label": "PHONE_NUMBER", "pattern": [{"ORTH": "("}, {"SHAPE": "ddd"}, {"ORTH": ")"}, {"SHAPE": "ddd"}, {"ORTH": "-", "OP": "?"}, {"SHAPE": "dddd"}]},
               {"label": "Base Rent", "pattern": "Base Rent"},
               {"label": "MONEY", "pattern": [{"ORTH": "$"}, {"LIKE_NUM": True}]},
               #{"label": "MONEY", "pattern": "$"},
               #{"label": "Abstract_Keywords", "pattern": [{'LOWER': {'IN': ['landlord', 'tenant', 'effective date', 'commencement date', 'base rent']}}]}, 
               {"label": "DATE_FORMAT", "pattern": [{"LOWER": {"REGEX": "(January|February|March|April|May|June|July|August|September|October|November|December)( ) (\d){1,2}(\, ) (\d){1,4}"}}]} 
               #{"label": "DATE_FORMAT", "pattern": [{"POS": "PROPN"}, {"LIKE_NUM": True}, {"IS_PUNCT": True}, {"LIKE_NUM": True}]}, 
               #{"label": "DATE_FORMAT", "pattern": [{"POS": "PROPN"}, {"LIKE_NUM": True}, {"text": ","}, {"LIKE_NUM": True}]}, 
            ]

#Create the EntityRuler
#ruler = nlp.add_pipe("entity_ruler", before="ner")
#ruler = nlp.add_pipe("entity_ruler", before="ner")

ruler.add_patterns(patterns)

for ent in doc.ents:
    print (ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# September 14, 2021 165 183 DATE
# St John’s Fletcher LLC 199 221 ORG
# Mosaic Group, LLC 235 252 ORG
# 235 St Johns Road 306 323 FAC
# Fletcher 325 333 GPE
# NC 335 337 GPE
# 4,900 SF 397 405 QUANTITY
# 3 437 438 CARDINAL
# 3 491 492 CARDINAL
# Last day of the 63rd full calendar month 498 538 DATE
# 4 596 597 CARDINAL
# 4 635 636 CARDINAL
# April 1,2022 - March 31,2023 642 670 DATE
# 6,941.67 673 681 MONEY
# April 1,2023 -March 31,2024 692 719 DATE
# 7,149.92 722 730 MONEY
# April 1,2024-March 31,2025 741 767 DATE
# 7,364.41 770 778 MONEY
# April 1,2025-March 31, 2026 789 816 DATE
# 7,585.35 819 827 MONEY
# April 1,2026 - March 31, 2027 838 867 DATE
# 7,812.91 870 878 MONEY
# 7 916 917 CARDINAL
# 26 1068 1070 CARDINAL
# 6,941.67 1077 1085 MONEY
# 28 1128 1130 CARDINAL
# Mosaic Group, LLC 1136 1153 ORG
# 814 1155 1158 CARDINAL
# 126 1178 1181 CARDINAL
# Charlotte 1183 1192 GPE
# North Carolina 1194 1208 GPE
# 28217 1209 1214 CARDINAL
# 28 1277 1279 CARDINAL
# ...

# %%
TRAIN_DATA = []

#ruler = nlp.add_pipe("tagger")
#ruler = nlp.add_pipe("attribute_ruler")

#iterate over the corpus again
for sentence in corpus:
    doc = nlp(sentence)
    
    #remember, entities needs to be a dictionary in index 1 of the list, so it needs to be an empty list
    entities = []
    
    #extract entities
    for ent in doc.ents:

        #appending to entities in the correct format
        entities.append([ent.start_char, ent.end_char, ent.label_])
        
       
    TRAIN_DATA.append([sentence, {"entities": entities}])
    
 
print (TRAIN_DATA)
# Out:
# [['\n\n\nC:/Users/RECAM/Large_module_NER\\ASH - St Johns Mosaic Lease - 09142021 (signed)_Text.txt\n\n\nLEASE AGREEMENT.', {'entities': [[94, 109, 'Lease']]}], ['BASIC LEASE INFORMATION.', {'entities': []}], ['Effective Date of Lease: --- September 14, 2021.', {'entities': [[0, 14, 'Effective']]}], ['Landlord: --- St John’s Fletcher LLC.', {'entities': [[0, 8, 'LL'], [24, 32, 'City']]}], ['Tenant: --- Mosaic Group, LLC.', {'entities': [[0, 6, 'TT']]}], ['Name and Location of Building: [Paragraph 1(a)) --- 235 St Johns Road, Fletcher, NC 28732.', {'entities': [[71, 79, 'City'], [81, 83, 'State']]}], ['Net Rentable Area of Premises: [Paragraph 1(b)] --- 4,900 SF.', {'entities': []}], ['Term Commencement: [Paragraph 3] --- Commencement Date.', {'entities': [[37, 54, 'Commencement']]}], ['Term Expiration: [Paragraph 3] --- Last day of the 63rd full calendar month following the Commencement Date (as defined in Paragraph 4 hereof).', {'entities': [[90, 107, 'Commencement']]}], ['Base Rent 
# ...

# %%
import srsly
import typer
import warnings
from pathlib import Path

import spacy
from spacy.tokens import DocBin

def convert(lang: str, TRAIN_DATA, output_path: Path):
    nlp = spacy.blank(lang)
    db = DocBin()
    for text, annot in TRAIN_DATA:
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label)
            if span is None:
                msg = f"Skipping entity [{start}, {end}, {label}] in the following text because the character span '{doc.text[start:end]}' does not align with token boundaries:\n\n{repr(text)}\n"
                warnings.warn(msg)
            else:
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    db.to_disk(output_path)

# %%
convert("en", TRAIN_DATA, "data/train.spacy")
convert("en", TRAIN_DATA, "data/valid.spacy")

# %%
# !python -m spacy init fill-config data/base_config.cfg data/config.cfg
# Out:
# [+] Auto-filled config with all values
# [+] Saved config
# data\config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# !python -m spacy train data/config.cfg --output ./models/output
# Out:
# [i] Saving to output directory: models\output
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     36.72    0.00    0.00    0.00    0.00
#   1     200        716.40   1007.14   47.95   51.25   45.05    0.48
#   3     400       7763.13    275.92   86.36   89.41   83.52    0.86
#   5     600       7148.65    140.50   95.56   96.63   94.51    0.96
#   8     800         33.61     45.08   96.70   96.70   96.70    0.97
#  11    1000         49.94     36.48   97.80   97.80   97.80    0.98
#  15    1200         16.35     11.55  100.00  100.00  100.00    1.00
# ...

# %%
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_trf")

# %%
trained_nlp = spacy.load("C:/Users/RECAM/models/output/model-best")
#text = "LEASE AGREEMENT. BASIC LEASE INFORMATION. Effective Date of Lease: --- September 14, 2021. Landlord: --- St John’s Fletcher LLC. Tenant: --- Mosaic Group, LLC. Name and Location of Building: [Paragraph 1(a)) --- 235 St Johns Road, Fletcher, NC 28732. Net Rentable Area of Premises: [Paragraph 1(b)] --- 4,900 SF. Term Commencement: [Paragraph 3] --- Commencement Date. Term Expiration: [Paragraph 3] --- Last day of the 63rd full calendar month following the Commencement Date (as defined in Paragraph 4 hereof). Base Rent (NNN): [Paragraph 4] --- April 1,2022 - March 31,2023: $6,941.67 per month April 1,2023 -March 31,2024: $7,149.92 per month April 1,2024-March 31,2025: $7,364.41 per month April 1,2025-March 31, 2026; $7,585.35 per month April 1,2026 - March 31, 2027: $7,812.91 per month. Permitted Use: [Paragraph 7] --- General office use and providing therapy services to youth with autism and related activities (as provided herein). Security Deposit: [Paragraph 26] --- $6,941.67. Tenant’s address for Notices: [Paragraph 28] --- Mosaic Group, LLC. 814 Tyvola Road, Suite 126. Charlotte, North Carolina 28217. Landlord’s Address for Notices & Rent. Payments:. [Paragraph 28] --- St John’s Fletcher, LLC P.O. Box 1741 Arden, NC 28704 Attn: Peter Raffalski. Exhibits:. Exhibit A - Legal Description of Building. Exhibit B - Landlord & Tenant. Improvement Work. Exhibit C - Designated Parking Spaces. Exhibit D - Declaration of. Commencement Date --- . CHAR2\2453742v6. The provisions of the Lease identified above in brackets are those provisions where reference to particular Basic Lease Information appears. Each reference to an item of Basic Lease Information, wherever it may appear in the Lease, shall incorporate the applicable Basic Lease Information set forth above. In the event of any conflict between any Basic Lease Information and the Lease, the latter shall control. 2. CHAR2\2453742v6. LEASE AGREEMENT. THIS LEASE AGREEMENT (this “Lease”), dated September 14, 2021 (the “Effective Date”), is made and entered into by and between St John’s Fletcher LLC, a North Carolina limited liability company (“Landlord”) and Mosaic Group, LLC, a South Carolina limited liability company (“Tenant”). WITNESSETH:. Landlord hereby leases to Tenant, and Tenant hereby leases from Landlord the Premises described in paragraph 1(b) below for the term and subject to the terms, covenants, agreements and conditions hereinafter set forth, to each and all of which Landlord and Tenant hereby mutually agree. 1. --- Definitions. Unless the context otherwise specified or requires, the following terms shall have the meanings herein specified:. (a) --- The term “Building” shall mean the parcel of real property described on Exhibit A attached hereto, situated in the location and commonly known by the name specified in the Basic Lease Information, which name the Landlord may change at any time, and all other improvements on or appurtenances to such parcel. (b) --- The term “Premises” shall mean Suite 50 of the Building. The Premises contains the net rentable area specified in the Basic Lease Information. (c) --- The term “Common Area” shall refer to all areas, spaces, equipment, special services, improvements, and facilities in or near the Building provided by Landlord for the common or joint use and benefit of the occupants of the Building, their officers, agents, employees, servants, customers and invitees, including but not limited to, all parking areas, access roads, streets, driveways, entrances, exits, sidewalks, courts, loading docks, package pick-up stations, ramps, corridors, halls, stairs, retaining walls, easements, and landscaped areas. (d) --- The term “Lease Year” shall mean each consecutive twelve (12) calendar month period beginning on the Commencement Date during the Term, and the last Lease Year shall end upon the expiration of the Term. (e) --- The term “Property Taxes” shall mean any form of real or personal property taxes, assessments, special assessments, fees, charges, levies, penalties, service payments in lieu of taxes, excises, assessments and charges for transit, housing or any other purpose, impositions or taxes of every kind and nature whatsoever, assessed or levied or imposed by any authority having the direct or indirect power to tax including, without limitation, any city, county, state, or federal government, or any improvement or assessment district of any kind or nature whatsoever, whether or not consented to or joined in by Landlord against the Building or any legal or equitable interest of Landlord therein or any personal property of Landlord used in the operation thereof, whether now or hereafter imposed, whether or not now customary or in the contemplation of the parties on the date of this Lease, excepting only taxes measured by the net income of Landlord from all sources; provided that Property taxes shall not include any taxes, assessments or other charges payable by Tenant pursuant to paragraph 5 below. However, “Property Taxes” shall not include any (x) charges, fees, penalties or interest asserted due to Landlord’s failure to timely pay taxes (except to the extent due to Tenant’s failure to pay the same as and when due hereunder), (y) except for taxes on rent or leasehold estates; taxes on or relating to inheritance, estates, succession, transfer, gift, franchise, net profits; income excise; capital stock; assets (other than ad valorem. 3. CHAR2\2453742v6. real estate taxes); franchise, margin, use, transaction, business activity or privilege tax imposed by Landlord, or (z) “tap-in” or other development fees specific to the initial construction of the Building. (f) --- The term “Rent” or “Rental” shall mean all payments due from Tenant to Landlord; including, but not limited to, Base Rent and all other additional rent, as provided in this Lease. 2. --- Premises. Tenant hereby acknowledges that, except as otherwise expressly set forth herein, the Premises shall be delivered in “as is” condition and that Landlord otherwise has no obligation to alter, repair, renovate, or render fit for Tenant’s occupancy, any part of the Premises. Landlord represents and warrants that, as of the Effective Date and as of the Commencement Date (defined in Section 4(a) below), as applicable, (a) the mechanical systems and utilities serving the Premises are and will be in good working order and the Premises and the Building are and will be in compliance with all issued permits, laws and ordinances for the use and occupancy thereof, and (b) the Premises and Common Area comply with all applicable laws, ordinances and governmental regulations, including, without limitation, the Americans with Disabilities Act of 1990, as amended from time to time prior to or after the Effective Date (the “ADA”) (and Landlord shall remain liable throughout the Term, at its sole expense, for keeping the Common Areas in compliance with all applicable laws, including without limitation the ADA). Tenant shall have access to the Premises 24 hours a day, 7 days a week, 365 days a year at its sole discretion. 3. --- Term. (a) --- Initial Term. The “Term” of this Lease shall commence on the earlier of (i) the date Tenant receives a temporary certificate of occupancy with respect to the Premises, or (ii) 90 days following the date hereof (the “Commencement Date”) and, unless sooner terminated or extended in accordance with the provisions of this Lease, shall end on March 31, 2027. On or before the Commencement Date, the parties shall execute a Declaration of Commencement Date in substantially the form attached hereto as Exhibit D, provided that the execution of such declaration shall not be condition precedent to the commencement of this Lease. Notwithstanding the foregoing, Tenant shall be entitled to occupy the Premises on or before September --- 2021. Tenant shall give Landlord written notice of the. receipt of the Certificate of Occupancy, together with a copy thereof certified as true and correct by Tenant in accordance with the terms of Exhibit B. (b) --- Renewal Options. Tenant will have two (2), five (5)-year, renewal options (each, a “Renewal Option”) to extend the Term (each, a “Renewal Term”). Each Renewal Term will commence on the day after the then-current expiration date of the Lease and expire five (5) years thereafter. A RENEWAL OPTION MAY BE EXERCISED BY TENANT BY PROVIDING WRITTEN NOTICE TO LANDLORD (A “RENEWAL NOTICE”) NOT LATER THAN ONE HUNDRED TWENTY (120) DAYS PRIOR TO THE THEN-CURRENT EXPIRATION DATE OF THE TERM. Each Renewal Term will contain the same covenants, terms, and conditions as in this Lease for the Term, except the Base Rent payable monthly in connection with the Premises during each Renewal Term shall continue with three percent (3%) annual increases over the Base Rent due the previous Lease Year. 4. --- Rent. Tenant shall pay to Landlord as rental for the use and occupancy of the Premises, at the times and in the manner hereinafter provided, the following sums of money (each such amount being included in the term “Rent”)"
doc = trained_nlp(text)

for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# LEASE AGREEMENT Lease
# Effective Date Effective
# Landlord LL
# Fletcher City
# Tenant TT
# Fletcher City
# NC State
# Commencement Date Commencement
# Commencement Date Commencement
# Base Rent Base Rent
# $6,941.67 MONEY
# $7,149.92 MONEY
# $7,364.41 MONEY
# $7,585.35 MONEY
# $7,812.91 MONEY
# $6,941.67 MONEY
# Tenant TT
# address Location
# Landlord LL
# Fletcher City
# NC State
# Landlord LL
# Tenant TT
# Commencement Date Commencement
# LEASE AGREEMENT Lease
# LEASE AGREEMENT Lease
# Effective Date Effective
# Fletcher City
# Landlord LL
# Tenant TT
# Landlord LL
# Tenant TT
# Tenant TT
# Landlord LL
# Landlord LL
# Tenant TT
# Landlord LL
# Landlord LL
# Commencement Date Commencement
# Landlord LL
# Landlord LL
# Landlord LL
# Landlord LL
# Tenant TT
# Landlord LL
# Tenant TT
# Landlord LL
# Tenant TT
# Landlord LL
# Base Rent Base Rent
# Tenant TT
# Landlord LL
# Tenant TT
# Landlord LL
# Effective Date Effective
# Commencement Date Commencement
# Effective Date Effective
# ...

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br><br><br>C:/Users/RECAM/Large_module_NER\ASH - St Johns Mosaic Lease - 09142021 (signed)_Text.txt<br><br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEASE AGREEMENT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lease</span>
# </mark>
# . BASIC LEASE INFORMATION.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Effective Date
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Effective</span>
# </mark>
#  of Lease: --- September 14, 2021.
# ...
